# %% [markdown]
# # <span style='color:blue'>Project - Superstore Sales Data Analysis</span>

# %% [markdown]
# ### <span style='color:darkmagenta'>About the Dataset(Superstore Sales Analysis)</span>

# %% [markdown]
# Here are the definitions for a few of the columns:
#
# * **Ship Mode:** Mode of shipment used for shipment delivery.
#
# * **Segment:** Customer segment where product was shipped to.
#
# * **Country:** Country in which the shipment was delivered.
#
# * **City:** City in which shipment was delivered.
#
# * **State:** State in which shipment was delivered.
#
# * **Postal Code:** Postal code the shipment was delivered to.
#
# * **Region:** Country region.
#
# * **Category:** The category product belongs to.
#
# * **Sub-Category:** Sub-category of the product.
#
# * **Sales:** Sales made.

# %% [markdown]
# ### <span style='color:steelblue'>Import the Required Libraries</span>

# %%
# importing required library

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### <span style='color:darkmagenta'>Reading/Loading Superstore Sales Analysis data</span>

# %%
# Reading SampleSuperstore.csv file and assigned the given dataset into variable i.e 'df'

df = pd.read_csv(r'SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### <span style='color:steelblue'>Data Exploration</span>

# %%
# 1. Fetching Top 5 records from dataset

df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# 2. Fetching bottom 5 records from dataset

df.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# 3. summary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# 4. Statistical summary of dataset

df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# 5. Number of Columns in dataset

df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# 6. Shape of dataset

df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ### <span style='color:darkmagenta'>Data Cleaning</span>

# %%
# 1. checking missing/null values present in dataset 

missing_values = df.isnull().sum()
missing_values

# There is no missing or null values present in dataset
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# 2. dropping unwanted columns

# checking value count of Country column

df['Country'].value_counts()

# In Country column there is only single entry of 'United States' as we don't need any analysis to be done based on it, we can drop country column
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
#dropping Country column

df=df.drop('Country',axis=1)

df.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### <span style='color:steelblue'>Descriptive Statistics</span>

# %% [markdown]
# **Calculating Total Sale:**

# %%
total_sales = df['Sales'].sum()

print("Total Sale is:", total_sales)
# Out:
# Total Sale is: 2297200.8603000003

# %% [markdown]
# **Calculate Average Order Value:**

# %%
average_order_value = df['Sales'].mean()

print("Average Order Value of Sale:", average_order_value)
# Out:
# Average Order Value of Sale: 229.85800083049833

# %% [markdown]
# **Calculating Total Quantity:**

# %%
total_quantity = df["Quantity"].sum()

print("Total Quantity is:", total_quantity)
# Out:
# Total Quantity is: 37873

# %% [markdown]
# **Calculating Total Profit:**

# %%
total_profit = df["Profit"].sum()
print("Total Profit:", total_profit)
# Out:
# Total Profit: 286397.0217

# %% [markdown]
# **Calculating Average Profit:**

# %%
average_profit = df["Profit"].mean()
print("Average Profit:", average_profit)
# Out:
# Average Profit: 28.65689630778467

# %% [markdown]
# **Calculating Total Discount:**

# %%
total_discount = df["Discount"].sum()
print("Total Discount:", total_discount)
# Out:
# Total Discount: 1561.09

# %% [markdown]
# ### We can analyse the our data into three different areas:
# - **1.Customer Segmentation**
# - **2.Product Analysis**
# - **3.Order Analysis**

# %% [markdown]
# ### <span style='color:darkmagenta'>1. Customer Segmentation</span>

# %%
# finding unique values from columns

# 1. Segment unique values
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
# 2. Segment value count

df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %% [markdown]
# - **Most Profitable Customer Segment**

# %%
Profitable_Cust_Seg= pd.DataFrame(df.groupby(['Segment'])[['Profit']].mean())
Profitable_Cust_Seg

# Most profitable customer segment is "Home Office"
# Out:
#                 Profit
# Segment
# Consumer     25.836873
# Corporate    30.456667
# Home Office  33.818664

# %%
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size':14})
ax = sns.barplot(data = Profitable_Cust_Seg, x = Profitable_Cust_Seg.index, y = Profitable_Cust_Seg.Profit)
plt.title("Customer Segment Profitability",color='indigo',fontsize=12,fontweight='bold')
# Annotate the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')
plt.show()

'''Here is visualization of most profitable customer segment. From graph we can say that most profitable customer segment is "Home Office"'''
# Out:
# 'Here is visualization of most profitable customer segment. From graph we can say that most profitable customer segment is "Home Office"'

# %% [markdown]
# - **Most Profitable customer region:**

# %%
profitable_region = pd.DataFrame(df.groupby(['Region'])['Profit'].sum().reset_index())
profitable_region
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
plt.figure(figsize=(12,6))
plt.pie(profitable_region.Profit, labels = profitable_region.Region, startangle = 90, autopct = "%1.0f%%", explode = [0, 0, 0, 0.1])
plt.title("Most Profitable by Region", color='indigo',fontsize=14,fontweight='bold')
plt.show()

'''Most profitable Customer Segment is "West".'''
# Out:
# 'Most profitable Customer Segment is "West".'

# %% [markdown]
# **Graph of count of Customer Segments**

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df.Segment)
plt.title('Count of Customer Segments',color='Black',fontsize=15,fontweight='bold')
plt.rcParams.update({'font.size':14});
# Annotate the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')
plt.show()

'''In Consumer segment cout is very high. But here we observe count of "Home Office" segment is very low. 
So improvement is need in this segment'''
# Out:
# 'In Consumer segment cout is very high. But here we observe count of "Home Office" segment is very low. \nSo improvement is need in this segment'

# %% [markdown]
# ### <span style='color:steelblue'>2. Product Analysis</span>

# %%
# Ship Mode unique values

df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
# Ship Mode value count

df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
# Category unique values

df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Category value counts

df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
# Sub-Category unique values

df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
# Sub-Category value count

df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# **Graph of Sub-Category wise Sales data**

# %%
plt.figure(figsize=(28,8))
plt.bar(df['Sub-Category'],df['Sales']);
plt.title('Sub-Category wise Sales data',color='red',fontsize=20,fontweight='bold')
plt.rcParams.update({'font.size':14});
plt.xlabel('Sub-Category');
plt.ylabel('Sales');
plt.show()

'''Comparison in overall supermarket data, Fasteners, Labels, Furnishings, Art, paper, Envelopes, etc., sub-categories have very fewer sales, that’s why it needs to be improved.'''
# Out:
# 'Comparison in overall supermarket data, Fasteners, Labels, Furnishings, Art, paper, Envelopes, etc., sub-categories have very fewer sales, that’s why it needs to be improved.'

# %% [markdown]
# **Graph of Sub-Category wise Discount**

# %%
plt.figure(figsize=(28,8))
plt.bar(df['Sub-Category'],df['Discount']);
plt.title('Sub-Category wise Discount',color='Green',fontsize=20,fontweight='bold')
plt.rcParams.update({'font.size':14});
plt.xlabel('Sub-Category');
plt.ylabel('Sales');
plt.show()

'''Here Bookcase, tables, phones, machines and copiers has more discount that way sale is also more'''
# Out:
# 'Here Bookcase, tables, phones, machines and copiers has more discount that way sale is also more'

# %% [markdown]
# **Graph of Count of Sub-Category(Best Performing Sub-Category)**

# %%
plt.figure(figsize=(20,8))
plt.rcParams.update({'font.size':10})
ax = sns.countplot(x='Sub-Category',data=df)
plt.title('Count of Best Performing Sub-Category',color='indigo',fontsize=15,fontweight='bold')
# Annotate the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')
plt.show()

'''From the below graph we observe that "Machines" and "Copiers" has very low count. Improvement is needed in these two Sub-Category'''
# Out:
# 'From the below graph we observe that "Machines" and "Copiers" has very low count. Improvement is needed in these two Sub-Category'

# %% [markdown]
# **Graph of Count of Category(Best Performing Category)**

# %%
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size':12})
ax=sns.countplot(x='Category',data=df)
plt.title('Count of Best Performing Category',color='indigo',fontsize=12,fontweight='bold')
# Annotate the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')
plt.show()

'''Here best performing category is "Office Supplies"'''
# Out:
# 'Here best performing category is "Office Supplies"'

# %% [markdown]
# **Graph of Total Profit and Sales per Sub-Category**

# %%
plt.figure(figsize=(10,8))
df.groupby('Sub-Category')[['Profit','Sales']].agg(['sum']).plot.bar()
plt.rcParams.update({'font.size':10})
plt.title('Total Profit and Sales per Sub-Category',color='Brown',fontsize=18,fontweight='bold')
plt.legend(['Sales','Profit'])
plt.show()
'''From graph we can say that Highest profit is earned in Chairs & Phones while Selling price for Copiers is extremely high compared to other products.'''
# Out:
# 'From graph we can say that Highest profit is earned in Chairs & Phones while Selling price for Copiers is extremely high compared to other products.'

# %% [markdown]
# **Top 10 Most Selling Sub-Category**

# %%
top_10_sub_cat = pd.DataFrame(df.groupby(['Sub-Category']).sum()['Quantity'])

top_10_sub_cat.sort_values('Quantity',ascending=False)[:10]
# Out:
#               Quantity
# Sub-Category
# Binders           5974
# Paper             5178
# Furnishings       3563
# Phones            3289
# Storage           3158
# Art               3000
# Accessories       2976
# Chairs            2356
# Appliances        1729
# Labels            1400

# %% [markdown]
# **Most Profitable Category in Sub-Category**

# %%
pro_cat = pd.DataFrame(df.groupby(['Category','Sub-Category']).sum()['Profit'])

pro_cat.sort_values('Profit',ascending=False)
# Out:
#                                   Profit
# Category        Sub-Category
# Technology      Copiers       55617.8249
#                 Phones        44515.7306
#                 Accessories   41936.6357
# Office Supplies Paper         34053.5693
#                 Binders       30221.7633
# Furniture       Chairs        26590.1663
# Office Supplies Storage       21278.8264
#                 Appliances    18138.0054
# Furniture       Furnishings   13059.1436
# Office Supplies Envelopes      6964.1767
#                 Art            6527.7870
#                 Labels         5546.2540
# Technology      Machines       3384.7569
# Office Supplies Fasteners       949.5182
#                 Supplies      -1189.0995
# Furniture       Bookcases     -3472.5560
#                 Tables       -17725.4811

# %% [markdown]
# ### <span style='color:darkmagenta'>3. Order Analysis</span>

# %% [markdown]
# **Most Ordered Quantity by Region**

# %%
most_orderd_quantity_region = pd.DataFrame(df.groupby(['Region'])['Quantity'].sum().reset_index())
most_orderd_quantity_region
# Out:
#     Region  Quantity
# 0  Central      8780
# 1     East     10618
# 2    South      6209
# 3     West     12266

# %%
plt.figure(figsize=(12,6))
plt.pie(most_orderd_quantity_region.Quantity, labels = most_orderd_quantity_region.Region, startangle = 90, autopct = "%1.0f%%", explode = [0, 0, 0, 0.1])
plt.title("Most Ordered Quantity by Region", color='indigo',fontsize=14,fontweight='bold')
plt.show()

'''Most of the orders are place by Customer in "West" region.'''
# Out:
# 'Most of the orders are place by Customer in "West" region.'

# %% [markdown]
# **Graph of Sales by Ship Mode**

# %%
plt.figure(figsize=(28,8))
plt.bar(df['Ship Mode'],df['Sales']);  
plt.title('Ship Mode wise Sales',color='Black',fontsize=15,fontweight='bold')
plt.rcParams.update({'font.size':14});
plt.xlabel('Ship Mode');
plt.ylabel('Sales');
plt.show()
'''Here we observe that the sales are high if the ship mode is standard class, and sales are low if the ship mode is either second class or same day. Most of the orders are placed using Standard class shipment mode '''
# Out:
# 'Here we observe that the sales are high if the ship mode is standard class, and sales are low if the ship mode is either second class or same day. Most of the orders are placed using Standard class shipment mode '

# %% [markdown]
# **Top 10 Most ordered Sub-Category**

# %%
top_10_sub_cat = pd.DataFrame(df.groupby(['Sub-Category']).sum()['Quantity'])

top_10_sub_cat.sort_values('Quantity',ascending=False)[:10]
# Out:
#               Quantity
# Sub-Category
# Binders           5974
# Paper             5178
# Furnishings       3563
# Phones            3289
# Storage           3158
# Art               3000
# Accessories       2976
# Chairs            2356
# Appliances        1729
# Labels            1400
